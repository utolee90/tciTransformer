# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
tt_ratio = [k*0.1 for k in range(1,9)]
t_len = ['48', '96', '192', '336', '720', '1500']

tt_mse = [3.1277761459350586, 1.7545785903930664, 0.8655498623847961,0.6006394624710083,0.35434436798095703,0.3080836236476898,0.2092275768518448,0.1968996673822403,]
tt_mae = [0.9336521625518799, 0.7461650967597961,0.4853510856628418,0.40085306763648987,0.3125822842121124,0.2778899073600769,0.24647946655750275,0.2239757925271988,]
tt_smae = [0.08624642342329025, 0.004500521346926689,0.017957603558897972,0.04003928601741791,0.00025608090800233185,-0.0026685562916100025,0.031577665358781815,0.01751919835805893,]
tt_mse_last = [3.1327712535858154, 3.265576124191284,1.274308443069458,0.8818804621696472,0.6724393367767334,0.5392399430274963,0.42989736795425415,0.388070285320282,]
tt_mae_last = [1.2210968732833862, 1.274723768234253,0.7813130617141724,0.6434867978096008,0.5527637600898743,0.4955928921699524,0.4537934958934784,0.4401102364063263,]
tt_smae_last = [0.07106222957372665, -0.05463176965713501,0.07365301996469498,0.12363573163747787,0.05741392448544502,0.08252985775470734,0.10539523512125015,0.082961805164814,]
tt_corr_last = [0.5778719213411861, 0.6620781431345818,0.7004128242318679,0.6571735976297871,0.6140231732748189,0.5353478084495136,0.4161782348567885,0.3578833637499211,]

len_mse = [0.24332907795906067,0.2092275768518448,0.19966788589954376,0.2031049132347107,0.1969037503004074,0.20528271794319153,]
len_mae = [0.2689672112464905,0.24647946655750275,0.24207903444766998,0.243536114692688,0.2478148639202118,0.26067662239074707,]
len_smae = [0.01939135417342186,0.031577665358781815,0.02051011100411415,0.013143835589289665,0.00040802123839966953,0.018779275938868523,]
len_mse_last = [0.5155163407325745,0.42989736795425415,0.40190646052360535,0.3842355012893677,0.4024374485015869,0.3905782401561737,]
len_mae_last = [0.49079617857933044,0.4537934958934784,0.4456075429916382,0.43665701150894165,0.44272974133491516,0.4446814954280853,]
len_smae_last = [0.07374979555606842,0.10539523512125015,0.06851406395435333,0.02179648168385029,-0.007966313511133194,0.021467961370944977]
len_corr_last = [0.35118216255789214,0.4161782348567885,0.44998029487175456,0.5119083799831103,0.5451660559721189,0.5254261839241011,]

# %%
# TT-ratio graph
fig, axs = plt.subplots(4,2, figsize=(10, 12))

axs[0,0].plot(tt_ratio, tt_mse)
axs[0,0].set_title("MSE")
axs[0,1].plot(tt_ratio, tt_mae)
axs[0,1].set_title("MAE")
axs[1,0].plot(tt_ratio, tt_smae)
axs[1,0].set_title("SMAE")
axs[2,0].plot(tt_ratio, tt_mse_last)
axs[2,0].set_title("MSE_LAST")
axs[2,1].plot(tt_ratio, tt_mae_last)
axs[2,1].set_title("MAE_LAST")
axs[3,0].plot(tt_ratio, tt_smae_last)
axs[3,0].set_title("SMAE_LAST")
axs[3,1].plot(tt_ratio, tt_corr_last)
axs[3,1].set_title("CORR")
# Out:
# Text(0.5, 1.0, 'CORR')

# %%
t_len = ['48', '96', '192', '336', '720', '1500']


fig, axs = plt.subplots(4,2, figsize=(10, 12))


axs[0,0].plot(t_len, len_mse)
axs[0,0].set_title("MSE")
axs[0,1].plot(t_len, len_mae)
axs[0,1].set_title("MAE")
axs[1,0].plot(t_len, len_smae)
axs[1,0].set_title("SMAE")
axs[2,0].plot(t_len, len_mse_last)
axs[2,0].set_title("MSE_LAST")
axs[2,1].plot(t_len, len_mae_last)
axs[2,1].set_title("MAE_LAST")
axs[3,0].plot(t_len, len_smae_last)
axs[3,0].set_title("SMAE_LAST")
axs[3,1].plot(t_len, len_corr_last)
axs[3,1].set_title("CORR")
# Out:
# Text(0.5, 1.0, 'CORR')
