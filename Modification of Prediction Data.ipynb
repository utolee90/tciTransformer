# %%
# 데이터 결과 조작을 통해 개선이 되는지 확인

from utils.metrics import *
import numpy as np
import pandas as pd

# %%
# 보정계획
# 1. 초기값 맞추기 - 메트릭 향상이 될까?
# 2. 전체 데이터 normalizing -> 결과값의 상대수치 보정 체크

# %%
# 테스트 조건이랑 결과값 불러오기
import os

result_path = './results/'

test_name_1 = "PEMS03_96_48_MiTransformer_PEMS03.npz_1722779515"
test_name_2 = "PEMS03_96_96_MiTransformer_PEMS03.npz_1722780482"

# %%
"""Namespace(is_training=1, model_id='PEMS03_96_48', model='iTransformer', data='PEMS', root_path='./dataset/PEMS/', data_path='PEMS03.npz', features='M', target='OT', freq='h', checkpoints='./checkpoints/', train_ratio=0.6, test_ratio=0.2, two_sided=False, seq_len=96, label_len=48, pred_len=48, enc_in=358, dec_in=358, c_out=358, d_model=512, n_heads=8, e_layers=4, d_layers=1, d_ff=512, moving_avg=25, factor=1, distil=True, dropout=0.1, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=32, patience=3, learning_rate=0.001, des='Exp', loss='MSE', lradj='type1', use_amp=False, first_val_adjustment=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, tcn_layers=3, tcn_kernel_size=2, tcn_dropout=0.1, tcn_uniform_layer=True, tcn_bias=True, augmented_token=False)
Use GPU: cuda:0
>>>>>>>start training : PEMS03_96_48_MiTransformer_PEMS03.npz_1722779515>>>>>>>>>>>>>>>>>>>>>>>>>>
train 15581
val 5099
test 5099
        iters: 100, epoch: 1 | loss: 0.4479537
        speed: 0.0799s/iter; left time: 380.1902s
        iters: 200, epoch: 1 | loss: 0.3090580
        speed: 0.0757s/iter; left time: 353.0353s
        iters: 300, epoch: 1 | loss: 0.2528221
        speed: 0.0765s/iter; left time: 348.7624s
        iters: 400, epoch: 1 | loss: 0.1748014
        speed: 0.0770s/iter; left time: 343.2848s
Epoch: 1 cost time: 37.58645749092102
Epoch: 1, Steps: 486 | Train Loss: 0.3020268 Vali Loss: 0.1975447 Test Loss: 0.2169103
Validation loss decreased (inf --> 0.197545).  Saving model ...
Updating learning rate to 0.001
        iters: 100, epoch: 2 | loss: 0.2277839
        speed: 0.6089s/iter; left time: 2603.1244s
        iters: 200, epoch: 2 | loss: 0.2139990
        speed: 0.0764s/iter; left time: 319.1045s
        iters: 300, epoch: 2 | loss: 0.2266210
        speed: 0.0771s/iter; left time: 314.2805s
        iters: 400, epoch: 2 | loss: 0.2241978
        speed: 0.0776s/iter; left time: 308.3149s
Epoch: 2 cost time: 37.785459995269775
Epoch: 2, Steps: 486 | Train Loss: 0.2353430 Vali Loss: 0.2283979 Test Loss: 0.2600447
EarlyStopping counter: 1 out of 3
Updating learning rate to 0.0005
        iters: 100, epoch: 3 | loss: 0.1963039
        speed: 0.6529s/iter; left time: 2473.7155s
        iters: 200, epoch: 3 | loss: 0.2122899
        speed: 0.0768s/iter; left time: 283.4017s
        iters: 300, epoch: 3 | loss: 0.2080100
        speed: 0.0772s/iter; left time: 277.0643s
        iters: 400, epoch: 3 | loss: 0.1764774
        speed: 0.0778s/iter; left time: 271.3225s
Epoch: 3 cost time: 37.78570294380188
Epoch: 3, Steps: 486 | Train Loss: 0.1858609 Vali Loss: 0.1636619 Test Loss: 0.1822726
Validation loss decreased (0.197545 --> 0.163662).  Saving model ...
Updating learning rate to 0.00025
        iters: 100, epoch: 4 | loss: 0.1835230
        speed: 0.6456s/iter; left time: 2132.4308s
        iters: 200, epoch: 4 | loss: 0.1485859
        speed: 0.0768s/iter; left time: 246.1115s
        iters: 300, epoch: 4 | loss: 0.1437088
        speed: 0.0784s/iter; left time: 243.1404s
        iters: 400, epoch: 4 | loss: 0.1398930
        speed: 0.0776s/iter; left time: 233.1550s
Epoch: 4 cost time: 38.06804275512695
Epoch: 4, Steps: 486 | Train Loss: 0.1625468 Vali Loss: 0.1585990 Test Loss: 0.1775990
Validation loss decreased (0.163662 --> 0.158599).  Saving model ...
Updating learning rate to 0.000125
        iters: 100, epoch: 5 | loss: 0.1345992
        speed: 0.6402s/iter; left time: 1803.5578s
        iters: 200, epoch: 5 | loss: 0.1684935
        speed: 0.0775s/iter; left time: 210.5361s
        iters: 300, epoch: 5 | loss: 0.1593997
        speed: 0.0796s/iter; left time: 208.2700s
        iters: 400, epoch: 5 | loss: 0.1367939
        speed: 0.0786s/iter; left time: 197.7359s
Epoch: 5 cost time: 38.313812255859375
Epoch: 5, Steps: 486 | Train Loss: 0.1543910 Vali Loss: 0.1508015 Test Loss: 0.1696772
Validation loss decreased (0.158599 --> 0.150802).  Saving model ...
Updating learning rate to 6.25e-05
        iters: 100, epoch: 6 | loss: 0.1595811
        speed: 0.6565s/iter; left time: 1530.3317s
        iters: 200, epoch: 6 | loss: 0.1245910
        speed: 0.0769s/iter; left time: 171.5213s
        iters: 300, epoch: 6 | loss: 0.1414293
        speed: 0.0770s/iter; left time: 164.1883s
        iters: 400, epoch: 6 | loss: 0.1461388
        speed: 0.0777s/iter; left time: 157.7830s
Epoch: 6 cost time: 37.84338712692261
Epoch: 6, Steps: 486 | Train Loss: 0.1499968 Vali Loss: 0.1490624 Test Loss: 0.1684245
Validation loss decreased (0.150802 --> 0.149062).  Saving model ...
Updating learning rate to 3.125e-05
        iters: 100, epoch: 7 | loss: 0.1389512
        speed: 0.6330s/iter; left time: 1167.7947s
        iters: 200, epoch: 7 | loss: 0.1589486
        speed: 0.0767s/iter; left time: 133.8336s
        iters: 300, epoch: 7 | loss: 0.1321301
        speed: 0.0775s/iter; left time: 127.4213s
        iters: 400, epoch: 7 | loss: 0.1607933
        speed: 0.0777s/iter; left time: 119.9993s
Epoch: 7 cost time: 37.80966234207153
Epoch: 7, Steps: 486 | Train Loss: 0.1475732 Vali Loss: 0.1473426 Test Loss: 0.1661289
Validation loss decreased (0.149062 --> 0.147343).  Saving model ...
Updating learning rate to 1.5625e-05
        iters: 100, epoch: 8 | loss: 0.1487503
        speed: 0.6605s/iter; left time: 897.6198s
        iters: 200, epoch: 8 | loss: 0.1659072
        speed: 0.0769s/iter; left time: 96.8177s
        iters: 300, epoch: 8 | loss: 0.1436848
        speed: 0.0775s/iter; left time: 89.8581s
        iters: 400, epoch: 8 | loss: 0.1424516
        speed: 0.0780s/iter; left time: 82.5890s
Epoch: 8 cost time: 37.96845722198486
Epoch: 8, Steps: 486 | Train Loss: 0.1462250 Vali Loss: 0.1467271 Test Loss: 0.1659681
Validation loss decreased (0.147343 --> 0.146727).  Saving model ...
Updating learning rate to 7.8125e-06
        iters: 100, epoch: 9 | loss: 0.1358378
        speed: 0.6420s/iter; left time: 560.4458s
        iters: 200, epoch: 9 | loss: 0.1273458
        speed: 0.0767s/iter; left time: 59.2642s
        iters: 300, epoch: 9 | loss: 0.1441768
        speed: 0.0773s/iter; left time: 52.0493s
        iters: 400, epoch: 9 | loss: 0.1361406
        speed: 0.0780s/iter; left time: 44.6780s
Epoch: 9 cost time: 38.053223609924316
Epoch: 9, Steps: 486 | Train Loss: 0.1453711 Vali Loss: 0.1466728 Test Loss: 0.1665965
Validation loss decreased (0.146727 --> 0.146673).  Saving model ...
Updating learning rate to 3.90625e-06
        iters: 100, epoch: 10 | loss: 0.1498297
        speed: 0.6438s/iter; left time: 249.1472s
        iters: 200, epoch: 10 | loss: 0.1507484
        speed: 0.0769s/iter; left time: 22.0797s
        iters: 300, epoch: 10 | loss: 0.1108099
        speed: 0.0774s/iter; left time: 14.4785s
        iters: 400, epoch: 10 | loss: 0.1284698
        speed: 0.0779s/iter; left time: 6.7799s
Epoch: 10 cost time: 37.894407510757446
Epoch: 10, Steps: 486 | Train Loss: 0.1449882 Vali Loss: 0.1462680 Test Loss: 0.1661169
Validation loss decreased (0.146673 --> 0.146268).  Saving model ...
Updating learning rate to 1.953125e-06
>>>>>>>testing : PEMS03_96_48_MiTransformer_PEMS03.npz_1722779515<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
test 5099
test shape: (5099, 1, 48, 358) (5099, 1, 48, 358)
test shape: (5099, 48, 358) (5099, 48, 358)
mse:0.1661168485879898, mae:0.27775219082832336, smae:0.010386365465819836, irr_ratio(3):0.05004523105454277
mse_last:0.1458328664302826, mae_last:0.2485782951116562, corr_last:0.7821784449965982, smae_last:0.07338132709264755, irr_ratio_last(3):0.058933124141988626
0   1
Args in experiment:
Namespace(is_training=1, model_id='PEMS03_96_96', model='iTransformer', data='PEMS', root_path='./dataset/PEMS/', data_path='PEMS03.npz', features='M', target='OT', freq='h', checkpoints='./checkpoints/', train_ratio=0.6, test_ratio=0.2, two_sided=False, seq_len=96, label_len=48, pred_len=96, enc_in=358, dec_in=358, c_out=358, d_model=512, n_heads=8, e_layers=4, d_layers=1, d_ff=512, moving_avg=25, factor=1, distil=True, dropout=0.1, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=32, patience=3, learning_rate=0.001, des='Exp', loss='MSE', lradj='type1', use_amp=False, first_val_adjustment=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, tcn_layers=3, tcn_kernel_size=2, tcn_dropout=0.1, tcn_uniform_layer=True, tcn_bias=True, augmented_token=False)
Use GPU: cuda:0
>>>>>>>start training : PEMS03_96_96_MiTransformer_PEMS03.npz_1722780482>>>>>>>>>>>>>>>>>>>>>>>>>>
train 15533
val 5051
test 5051
        iters: 100, epoch: 1 | loss: 0.8178483
        speed: 0.0811s/iter; left time: 385.0944s
        iters: 200, epoch: 1 | loss: 0.5476531
        speed: 0.0766s/iter; left time: 356.0701s
        iters: 300, epoch: 1 | loss: 0.7814999
        speed: 0.0772s/iter; left time: 351.1855s
        iters: 400, epoch: 1 | loss: 0.4756824
        speed: 0.0784s/iter; left time: 348.9711s
Epoch: 1 cost time: 38.07591104507446
Epoch: 1, Steps: 485 | Train Loss: 0.6201536 Vali Loss: 0.8675893 Test Loss: 0.9345442
Validation loss decreased (inf --> 0.867589).  Saving model ...
Updating learning rate to 0.001
        iters: 100, epoch: 2 | loss: 1.5782857
        speed: 0.6772s/iter; left time: 2888.7262s
        iters: 200, epoch: 2 | loss: 1.7504026
        speed: 0.0770s/iter; left time: 320.9887s
        iters: 300, epoch: 2 | loss: 2.0239613
        speed: 0.0777s/iter; left time: 316.0289s
        iters: 400, epoch: 2 | loss: 2.0530081
        speed: 0.0780s/iter; left time: 309.3954s
Epoch: 2 cost time: 38.24939179420471
Epoch: 2, Steps: 485 | Train Loss: 1.8158519 Vali Loss: 2.0334857 Test Loss: 1.9690276
EarlyStopping counter: 1 out of 3
Updating learning rate to 0.0005
        iters: 100, epoch: 3 | loss: 2.1707697
        speed: 0.6693s/iter; left time: 2530.6322s
        iters: 200, epoch: 3 | loss: 1.9399191
        speed: 0.0771s/iter; left time: 283.7592s
        iters: 300, epoch: 3 | loss: 2.0602248
        speed: 0.0776s/iter; left time: 277.9428s
        iters: 400, epoch: 3 | loss: 2.3339713
        speed: 0.0779s/iter; left time: 271.3277s
Epoch: 3 cost time: 37.978867053985596
Epoch: 3, Steps: 485 | Train Loss: 2.0235174 Vali Loss: 2.0341070 Test Loss: 1.9660476
EarlyStopping counter: 2 out of 3
Updating learning rate to 0.00025
        iters: 100, epoch: 4 | loss: 1.9129428
        speed: 0.6583s/iter; left time: 2169.8585s
        iters: 200, epoch: 4 | loss: 1.4012504
        speed: 0.0773s/iter; left time: 247.1809s
        iters: 300, epoch: 4 | loss: 1.1301616
        speed: 0.0777s/iter; left time: 240.4852s
        iters: 400, epoch: 4 | loss: 0.9821422
        speed: 0.0783s/iter; left time: 234.6570s
Epoch: 4 cost time: 38.27832889556885
Epoch: 4, Steps: 485 | Train Loss: 1.4200909 Vali Loss: 1.5922228 Test Loss: 1.6494440
EarlyStopping counter: 3 out of 3
Early stopping
>>>>>>>testing : PEMS03_96_96_MiTransformer_PEMS03.npz_1722780482<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
test 5051
test shape: (5051, 1, 96, 358) (5051, 1, 96, 358)
test shape: (5051, 96, 358) (5051, 96, 358)
mse:0.9345430135726929, mae:0.7478240728378296, smae:-0.21174731850624084, irr_ratio(3):0.02291191646877824
mse_last:0.992326021194458, mae_last:0.7631136775016785, corr_last:0.45127363689306543, smae_last:-0.21592183411121368, irr_ratio_last(3):0.03112832442420643
"""

# %%
# 원본데이터 불러와서 확인 -> Train data 조건 확인가능.
# 6: 2 : 2 -> origin scaler 
test_origin = './dataset/PEMS/PEMS03.npz'

data_load = np.load(test_origin)

# %%
for key in data_load.keys():
    print(key)
# Out:
# data

# %%
data_load['data'].shape # 26258*358
# Out:
# (26208, 358, 1)

# %%
# train, validation, test 데이터 불러오기
from data_provider.data_loader import Dataset_PEMS

new_dataset_train_1 = Dataset_PEMS('./dataset/PEMS/', flag='train', size=[96,48,48], features='M', data_path='PEMS03.npz', target='OT', scale=True, timeenc=0, freq='h', train_ratio=0.6, test_ratio=0.2)
new_dataset_val_1 = Dataset_PEMS('./dataset/PEMS/', flag='val', size=[96,48,48], features='M', data_path='PEMS03.npz', target='OT', scale=True, timeenc=0, freq='h', train_ratio=0.6, test_ratio=0.2)
new_dataset_test_1 = Dataset_PEMS('./dataset/PEMS/', flag='test', size=[96,48,48], features='M', data_path='PEMS03.npz', target='OT', scale=True, timeenc=0, freq='h', train_ratio=0.6, test_ratio=0.2)
new_dataset_train_2 = Dataset_PEMS('./dataset/PEMS/', flag='train', size=[96,48,96], features='M', data_path='PEMS03.npz', target='OT', scale=True, timeenc=0, freq='h', train_ratio=0.6, test_ratio=0.2)
new_dataset_val_2 = Dataset_PEMS('./dataset/PEMS/', flag='val', size=[96,48,96], features='M', data_path='PEMS03.npz', target='OT', scale=True, timeenc=0, freq='h', train_ratio=0.6, test_ratio=0.2)
new_dataset_test_2 = Dataset_PEMS('./dataset/PEMS/', flag='test', size=[96,48,96], features='M', data_path='PEMS03.npz', target='OT', scale=True, timeenc=0, freq='h', train_ratio=0.6, test_ratio=0.2)

# %%
new_dataset_train_1[0][0]
# Out:
# array([[-1.31515991, -1.31753128, -0.69704304, ..., -1.37026554,
#         -0.87508441, -0.8272967 ],
#        [-1.28936836, -1.29105349, -0.74687648, ..., -1.37026554,
#         -0.91591085, -0.83891818],
#        [-1.28936836, -1.29105349, -0.69081386, ..., -1.40592799,
#         -0.87508441, -0.89702559],
#        ...,
#        [-0.47693454, -0.41728627, -0.39804239, ..., -0.03886718,
#         -0.1946439 , -0.38568037],
#        [-0.29639369, -0.35109178, -0.53508435, ..., -0.24095443,
#         -0.27629676, -0.3624374 ],
#        [-0.39955989, -0.39080848, -0.42295911, ..., -0.31822308,
#         -0.24227473, -0.29270851]])

# %%
# train all data
all_data = data_load['data'][:,:,0]
train_data = all_data[:int(len(all_data)*0.6)]
val_data = all_data[int(len(all_data)*0.6):int(len(all_data)*0.8)]
test_data = all_data[int(len(all_data)*0.8):]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(train_data)
new_train_data = scaler.transform(train_data)
new_val_data = scaler.transform(val_data)
new_test_data = scaler.transform(test_data)

# %%
# 평균 계산
for rx in range(358):
    print(f"Variable {rx+1} Mean:", np.mean(new_train_data[:,rx]), np.mean(new_val_data[:,rx]), np.mean(new_test_data[:,rx]))
    print(f"Variable {rx+1} Std:", np.std(new_train_data[:,rx]), np.std(new_val_data[:,rx]), np.std(new_test_data[:,rx]))
# Out:
# Variable 1 Mean: 4.609218967662822e-17 -0.025594716418438142 -0.076405349083326
# Variable 1 Std: 0.9999999999999989 0.9887720828129879 0.9630622732778106
# Variable 2 Mean: 5.0611031801787856e-17 -0.027923280244457015 -0.09144069077663955
# Variable 2 Std: 1.0000000000000036 0.9857308768663842 0.9697686911303341
# Variable 3 Mean: -1.061927899412513e-16 -0.03723121435827436 -0.1004451528943615
# Variable 3 Std: 1.0000000000000004 1.00084793868206 0.9909583625781735
# Variable 4 Mean: 5.332233707688363e-17 -0.042383349192371765 -0.11379222383231101
# Variable 4 Std: 0.9999999999999976 0.9981173306749515 0.9827862446059688
# Variable 5 Mean: -9.715510569093204e-17 -0.03695207103310241 -0.09664723570302744
# Variable 5 Std: 0.9999999999999991 0.999537880955102 0.9832554308951164
# Variable 6 Mean: 5.1966684439335744e-17 -0.04099037846117874 -0.09932410335476408
# Variable 6 Std: 1.0000000000000042 0.9964207675160452 0.9917403372004032
# ...

# %%
# pred, true 평균, 표준편차 비교

test_pred_1 = np.load(result_path + test_name_1 + '/pred.npy')
test_true_1 = np.load(result_path + test_name_1 + '/true.npy')
test_pred_2 = np.load(result_path + test_name_2 + '/pred.npy')
test_true_2 = np.load(result_path + test_name_2 + '/true.npy')

# %%
# pred_1 vs true_1

# total, 
metric_keys = ["MSE", "MAE", "SMAE", "STD_ERR", "Mean_Corr", " ]
# MSE, MAE, Signed MAE, stdev of error, mean correlation, 
metric_obj = {}

for pn in range(test_pred_1.shape[0]):
# Out:
# (5099, 48, 358)

# %%
# error distribution - using Shapiro-Wilk Test
from scipy import stats

test_diff_1 = test_true_1 - test_pred_1
pv_non = []
for pn in range(358):
    shapiro_test = stats.shapiro(test_diff_1[0,:,pn])
    if shapiro_test.pvalue <0.05:
        print(f"Shapiro-Wilk test 결과 (var {pn+1}):", shapiro_test)
    else:
        pv_non.append(pn)

print()
print(pv_non)
# Out:
# Shapiro-Wilk test 결과 (var 1): ShapiroResult(statistic=0.7544628569294173, pvalue=1.398866280159533e-07)
# Shapiro-Wilk test 결과 (var 2): ShapiroResult(statistic=0.7615317129592185, pvalue=1.9432081702331697e-07)
# Shapiro-Wilk test 결과 (var 3): ShapiroResult(statistic=0.9302741941809767, pvalue=0.006979178266153224)
# Shapiro-Wilk test 결과 (var 4): ShapiroResult(statistic=0.8987354194912872, pvalue=0.0005724929558098554)
# Shapiro-Wilk test 결과 (var 5): ShapiroResult(statistic=0.8909006973703605, pvalue=0.00032387913304949385)
# Shapiro-Wilk test 결과 (var 6): ShapiroResult(statistic=0.9139246561865719, pvalue=0.001827513609816761)
# Shapiro-Wilk test 결과 (var 7): ShapiroResult(statistic=0.9264880364917581, pvalue=0.005072753423149504)
# Shapiro-Wilk test 결과 (var 8): ShapiroResult(statistic=0.7585478153493359, pvalue=1.6902618580502025e-07)
# Shapiro-Wilk test 결과 (var 9): ShapiroResult(statistic=0.7645617055186935, pvalue=2.2412684465117015e-07)
# ...

# %%
import matplotlib.pyplot as plt

# %%
# 마지막 변수 분포
OT_diff_dist = test_diff_1[:,:,357].reshape(-1)
# 히스토그램 생성 및 시각화
plt.figure(figsize=(10, 6))
plt.hist(OT_diff_dist, bins=100, color='blue', edgecolor='black', alpha=0.7)
plt.title('Histogram of error of ')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

print(np.mean(OT_diff_dist), np.std(OT_diff_dist))
# Out:
# 0.07338133 0.37476397

# %%
# 마지막 변수 분포
OT_diff_dist_1 = test_diff_1[0,:,357].reshape(-1)
# 히스토그램 생성 및 시각화
plt.figure(figsize=(5, 3))
plt.hist(OT_diff_dist, bins=1, color='blue', edgecolor='black', alpha=0.5)
plt.title('Histogram of error of ')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
len("TCiTransformer: Temporal Convolution Embedding-based Transformer for long-term time series forecasting")
# Out:
# 102
